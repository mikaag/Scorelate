# %%
# -*- coding: utf-8 -*-
"""
MIT Licence

Zoghbi Abderraouf
Change data to your location
"""

from keras import backend as K
from tensorflow.keras.layers import Layer, InputSpec
from keras.initializers import RandomUniform, Initializer, Constant
import numpy as np


class InitCentersRandom(Initializer):
    """ Initializer for initialization of centers of RBF network
        as random samples from the given data set.
    # Arguments
        X: matrix, dataset to choose the centers from (random rows
          are taken as centers)
    """

    def __init__(self, X):
        self.X = X

    def __call__(self, shape, dtype=None):
        assert shape[1] == self.X.shape[1]
        idx = np.random.randint(self.X.shape[0], size=shape[0])
        return self.X[idx, :]


class RBFLayer(Layer):
    """ Layer of Gaussian RBF units.
    # Example
    ```python
        model = Sequential()
        model.add(RBFLayer(10,
                           initializer=InitCentersRandom(X),
                           betas=1.0,
                           input_shape=(1,)))
        model.add(Dense(1))
    ```
    # Arguments
        output_dim: number of hidden units (i.e. number of outputs of the
                    layer)
        initializer: instance of initiliazer to initialize centers
        betas: float, initial value for betas
    """

    def __init__(self, output_dim, initializer=None, betas=1.0, **kwargs):
        self.output_dim = output_dim
        self.init_betas = betas
        if not initializer:
            self.initializer = RandomUniform(0.0, 1.0)
        else:
            self.initializer = initializer
        super(RBFLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        self.centers = self.add_weight(name='centers',
                                       shape=(self.output_dim, input_shape[1]),
                                       initializer=self.initializer,
                                       trainable=True)
        self.betas = self.add_weight(name='betas',
                                     shape=(self.output_dim,),
                                     initializer=Constant(
                                         value=self.init_betas),
                                     # initializer='ones',
                                     trainable=True)

        super(RBFLayer, self).build(input_shape)

    def call(self, x):

        C = K.expand_dims(self.centers)
        H = K.transpose(C-K.transpose(x))
        return K.exp(-self.betas * K.sum(H**2, axis=1))

        # C = self.centers[np.newaxis, :, :]
        # X = x[:, np.newaxis, :]

        # diffnorm = K.sum((C-X)**2, axis=-1)
        # ret = K.exp( - self.betas * diffnorm)
        # return ret

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

    def get_config(self):
        # have to define get_config to be able to use model_from_json
        config = {
            'output_dim': self.output_dim
        }
        base_config = super(RBFLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

from keras.initializers import Initializer
from sklearn.cluster import KMeans


class InitCentersKMeans(Initializer):
    """ Initializer for initialization of centers of RBF network
        by clustering the given data set.
    # Arguments
        X: matrix, dataset
    """

    def __init__(self, X, max_iter=100):
        self.X = X
        self.max_iter = max_iter

    def __call__(self, shape, dtype=None):
        assert shape[1] == self.X.shape[1]

        n_centers = shape[0]
        km = KMeans(n_clusters=n_centers, max_iter=self.max_iter, verbose=0)
        km.fit(self.X)
        return km.cluster_centers_

# Commented out IPython magic to ensure Python compatibility.
import numpy as np, pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Activation
from keras.optimizers import RMSprop
import matplotlib.pyplot as plt



data = pd.read_csv('olive.csv',header=None)
data.head(10) #Return 10 rows of data

datatrans=np.transpose(data)
# print(datatrans[0].value_counts())
datatrans[0].value_counts()[:].plot(kind='bar', alpha=0.5)
plt.xlabel('\n Figure 1: Répartition selon classes \n', fontsize='17', horizontalalignment='center')
plt.tick_params(axis='x',  direction='out', length=10, width=3)

# plt.show() #2300

#data spliting
X=data.iloc[2:570,:].values
y = data.iloc[0:1,:].values
#data rotation
X=np.transpose(X)
y=np.transpose(y)
# print('rotation ')
# print(X)
# print(y)
#standarizing
from sklearn.preprocessing import MinMaxScaler
X = MinMaxScaler().fit_transform(X)
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
y = ohe.fit_transform(y).toarray()
# print('resulats de scalling')
# print(X,y)

from sklearn.model_selection import train_test_split
from keras.optimizers import SGD
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=0)#80% train et 20% test

# from sklearn.preprocessing import StandardScaler
# sc_X = StandardScaler()
# X_train = sc_X.fit_transform(X_train)
# X_test = sc_X.transform(X_test)

# sc_y = StandardScaler()
# y_train = y_train.reshape((len(y_train), 1))
# y_train = sc_y.fit_transform(y_train)
# y_train = y_train.ravel()

print(X_train.shape)

model = Sequential()
rbflayer = RBFLayer(34,
                        initializer=InitCentersKMeans(X_train),
                        betas=3.0,
                        input_shape=(568,))
model.add(rbflayer)
model.add(Dense(4))
model.add(Activation('linear'))
model.compile(loss='mean_squared_error',
                  optimizer=RMSprop(), metrics=['accuracy'])
print(model.summary())
history1 = model.fit(X_train, y_train, epochs=1000, batch_size=32)

import matplotlib.pyplot as plt
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['loss'])
plt.title('train accuracy and loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['accuracy', 'loss'], loc='upper left')
plt.show()

# # saving to and loading from file
# z_model = f"Z_model.h5"
# print(f"Save model to file {z_model} ... ", end="")
# model.save(z_model)
# print("OK")

#model already saved in file
from tensorflow.keras.models import  load_model
newmodel1= load_model("Zoghbio.h5",
                          custom_objects={'RBFLayer': RBFLayer})
print("OK")

# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = newmodel1.evaluate(X_test, y_test, batch_size=32)
print("test loss:", results[0])
print("test accuracy:",results[1]*100,'%')

# y_pred = newmodel1.predict(X_test)
# #Converting predictions to label
# pred = list()
# for i in range(len(y_pred)):
#     pred.append(np.argmax(y_pred[i]))
# #Converting one hot encoded test label to label
# test = list()
# for i in range(len(y_test)):
#     test.append(np.argmax(y_test[i]))

# from sklearn.metrics import accuracy_score
# a = accuracy_score(pred,test)
# print('Test Accuracy is:', a*100)
# Out:
# (48, 568)
# /Users/nikhil/Documents/401/CODE/Scorelate/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rbf_layer_6 (RBFLayer)      (None, 34)                19346
#
#  dense_6 (Dense)             (None, 4)                 140
#
#  activation_6 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 19,486
# Trainable params: 19,486
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 2023-04-04 14:34:45.947208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 1s 75ms/step - loss: 0.2720 - accuracy: 0.3125
# Epoch 2/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2681 - accuracy: 0.2917
# Epoch 3/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2652 - accuracy: 0.2917
# Epoch 4/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2622 - accuracy: 0.2917
# Epoch 5/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2589 - accuracy: 0.3542
# Epoch 6/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2558 - accuracy: 0.3333
# Epoch 7/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2529 - accuracy: 0.3542
# Epoch 8/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2501 - accuracy: 0.3542
# Epoch 9/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2473 - accuracy: 0.3542
# Epoch 10/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2447 - accuracy: 0.3542
# Epoch 11/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2422 - accuracy: 0.3750
# Epoch 12/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2400 - accuracy: 0.3750
# Epoch 13/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2379 - accuracy: 0.3750
# Epoch 14/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2359 - accuracy: 0.3750
# Epoch 15/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2340 - accuracy: 0.3750
# Epoch 16/1000
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2320 - accuracy: 0.3750
# Epoch 17/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2303 - accuracy: 0.3750
# Epoch 18/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2286 - accuracy: 0.3750
# Epoch 19/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2270 - accuracy: 0.3750
# Epoch 20/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2254 - accuracy: 0.3750
# Epoch 21/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2238 - accuracy: 0.3750
# Epoch 22/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2223 - accuracy: 0.4167
# Epoch 23/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2209 - accuracy: 0.4167
# Epoch 24/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2194 - accuracy: 0.4583
# Epoch 25/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2180 - accuracy: 0.4583
# Epoch 26/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2167 - accuracy: 0.4583
# Epoch 27/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2153 - accuracy: 0.5000
# Epoch 28/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2140 - accuracy: 0.5000
# Epoch 29/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2128 - accuracy: 0.5000
# Epoch 30/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2116 - accuracy: 0.5000
# Epoch 31/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2104 - accuracy: 0.5000
# Epoch 32/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2092 - accuracy: 0.4792
# Epoch 33/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2080 - accuracy: 0.4792
# Epoch 34/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2068 - accuracy: 0.5208
# Epoch 35/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2057 - accuracy: 0.5208
# Epoch 36/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2045 - accuracy: 0.5417
# Epoch 37/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2034 - accuracy: 0.5417
# Epoch 38/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2023 - accuracy: 0.5417
# Epoch 39/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2012 - accuracy: 0.5625
# Epoch 40/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2001 - accuracy: 0.5625
# Epoch 41/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1990 - accuracy: 0.5625
# Epoch 42/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1980 - accuracy: 0.5625
# Epoch 43/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1970 - accuracy: 0.5625
# Epoch 44/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1959 - accuracy: 0.5625
# Epoch 45/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1949 - accuracy: 0.5625
# Epoch 46/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1938 - accuracy: 0.5417
# Epoch 47/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1928 - accuracy: 0.5417
# Epoch 48/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1918 - accuracy: 0.5417
# Epoch 49/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1908 - accuracy: 0.5417
# Epoch 50/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1899 - accuracy: 0.5833
# Epoch 51/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1890 - accuracy: 0.5625
# Epoch 52/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1880 - accuracy: 0.5833
# Epoch 53/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1871 - accuracy: 0.5833
# Epoch 54/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1861 - accuracy: 0.5833
# Epoch 55/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1853 - accuracy: 0.5833
# Epoch 56/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1844 - accuracy: 0.5833
# Epoch 57/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1835 - accuracy: 0.5833
# Epoch 58/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1826 - accuracy: 0.5833
# Epoch 59/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1817 - accuracy: 0.5833
# Epoch 60/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1808 - accuracy: 0.5833
# Epoch 61/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1799 - accuracy: 0.5833
# Epoch 62/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1790 - accuracy: 0.5833
# Epoch 63/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1781 - accuracy: 0.5833
# Epoch 64/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1773 - accuracy: 0.5833
# Epoch 65/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1765 - accuracy: 0.6250
# Epoch 66/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1756 - accuracy: 0.6250
# Epoch 67/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1747 - accuracy: 0.6458
# Epoch 68/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1739 - accuracy: 0.6458
# Epoch 69/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1731 - accuracy: 0.6458
# Epoch 70/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1723 - accuracy: 0.6458
# Epoch 71/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1715 - accuracy: 0.6458
# Epoch 72/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1320 - accuracy: 0.7500
# Epoch 134/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1315 - accuracy: 0.7500
# Epoch 135/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1310 - accuracy: 0.7500
# Epoch 136/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1306 - accuracy: 0.7500
# Epoch 137/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1301 - accuracy: 0.7708
# Epoch 138/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1295 - accuracy: 0.7708
# Epoch 139/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1291 - accuracy: 0.7708
# Epoch 140/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1286 - accuracy: 0.7708
# Epoch 141/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1281 - accuracy: 0.7708
# Epoch 142/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1276 - accuracy: 0.7708
# Epoch 143/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1271 - accuracy: 0.7708
# Epoch 144/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1268 - accuracy: 0.7708
# Epoch 145/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1262 - accuracy: 0.7708
# Epoch 146/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1258 - accuracy: 0.7708
# Epoch 147/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1253 - accuracy: 0.7708
# Epoch 148/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1248 - accuracy: 0.7708
# Epoch 149/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1244 - accuracy: 0.7917
# Epoch 150/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1240 - accuracy: 0.7917
# Epoch 151/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1235 - accuracy: 0.7917
# Epoch 152/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1232 - accuracy: 0.7917
# Epoch 153/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1227 - accuracy: 0.7917
# Epoch 154/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1223 - accuracy: 0.7917
# Epoch 155/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1219 - accuracy: 0.7917
# Epoch 156/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1215 - accuracy: 0.7917
# Epoch 157/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1210 - accuracy: 0.7917
# Epoch 158/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1206 - accuracy: 0.7917
# Epoch 159/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1202 - accuracy: 0.7917
# Epoch 160/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1198 - accuracy: 0.7917
# Epoch 161/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1194 - accuracy: 0.7917
# Epoch 162/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1189 - accuracy: 0.7917
# Epoch 163/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1185 - accuracy: 0.7917
# Epoch 164/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1181 - accuracy: 0.7917
# Epoch 165/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1177 - accuracy: 0.7917
# Epoch 166/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1173 - accuracy: 0.7917
# Epoch 167/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1169 - accuracy: 0.7917
# Epoch 168/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1165 - accuracy: 0.7917
# Epoch 169/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1161 - accuracy: 0.7917
# Epoch 170/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1157 - accuracy: 0.7917
# Epoch 171/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1153 - accuracy: 0.7917
# Epoch 172/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1149 - accuracy: 0.8125
# Epoch 173/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1145 - accuracy: 0.8125
# Epoch 174/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1141 - accuracy: 0.8125
# Epoch 175/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1138 - accuracy: 0.8125
# Epoch 176/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1134 - accuracy: 0.8125
# Epoch 177/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1131 - accuracy: 0.8125
# Epoch 178/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1127 - accuracy: 0.8125
# Epoch 179/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1123 - accuracy: 0.8125
# Epoch 180/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1119 - accuracy: 0.8125
# Epoch 181/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1115 - accuracy: 0.8125
# Epoch 182/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1112 - accuracy: 0.8125
# Epoch 183/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1109 - accuracy: 0.8125
# Epoch 184/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1105 - accuracy: 0.8125
# Epoch 185/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1101 - accuracy: 0.8125
# Epoch 186/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1098 - accuracy: 0.8125
# Epoch 187/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1094 - accuracy: 0.8125
# Epoch 188/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1091 - accuracy: 0.8125
# Epoch 189/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1088 - accuracy: 0.8125
# Epoch 190/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1084 - accuracy: 0.8125
# Epoch 191/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1081 - accuracy: 0.8125
# Epoch 192/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1078 - accuracy: 0.8125
# Epoch 193/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1074 - accuracy: 0.8125
# Epoch 194/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1071 - accuracy: 0.8125
# Epoch 195/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0623 - accuracy: 0.8542
# Epoch 443/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0623 - accuracy: 0.8542
# Epoch 444/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0622 - accuracy: 0.8542
# Epoch 445/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.8542
# Epoch 446/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0619 - accuracy: 0.8542
# Epoch 447/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0618 - accuracy: 0.8542
# Epoch 448/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0618 - accuracy: 0.8542
# Epoch 449/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0616 - accuracy: 0.8542
# Epoch 450/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0616 - accuracy: 0.8542
# Epoch 451/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0615 - accuracy: 0.8542
# Epoch 452/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0614 - accuracy: 0.8542
# Epoch 453/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0612 - accuracy: 0.8542
# Epoch 454/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0611 - accuracy: 0.8542
# Epoch 455/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 0.8542
# Epoch 456/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0609 - accuracy: 0.8542
# Epoch 457/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0608 - accuracy: 0.8542
# Epoch 458/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0607 - accuracy: 0.8542
# Epoch 459/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0607 - accuracy: 0.8750
# Epoch 460/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0605 - accuracy: 0.8750
# Epoch 461/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0604 - accuracy: 0.8750
# Epoch 462/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0604 - accuracy: 0.8750
# Epoch 463/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0603 - accuracy: 0.8750
# Epoch 464/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0603 - accuracy: 0.8750
# Epoch 465/1000
# ...
# Epoch 858/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0369 - accuracy: 0.8958
# Epoch 859/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0366 - accuracy: 0.8958
# Epoch 860/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0366 - accuracy: 0.8958
# Epoch 861/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0365 - accuracy: 0.8958
# Epoch 862/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0364 - accuracy: 0.8958
# Epoch 863/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0364 - accuracy: 0.8958
# Epoch 864/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0361 - accuracy: 0.8958
# Epoch 865/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0361 - accuracy: 0.8958
# Epoch 866/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0360 - accuracy: 0.8958
# Epoch 867/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0360 - accuracy: 0.8958
# Epoch 868/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0359 - accuracy: 0.8958
# Epoch 869/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0357 - accuracy: 0.8958
# Epoch 870/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0358 - accuracy: 0.8958
# Epoch 871/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0356 - accuracy: 0.8958
# Epoch 872/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0355 - accuracy: 0.8958
# Epoch 873/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0353 - accuracy: 0.8958
# Epoch 874/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0353 - accuracy: 0.8958
# Epoch 875/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0352 - accuracy: 0.8958
# Epoch 876/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0354 - accuracy: 0.8958
# Epoch 877/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0351 - accuracy: 0.8958
# Epoch 878/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0350 - accuracy: 0.8958
# Epoch 879/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0352 - accuracy: 0.8958
# Epoch 880/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0349 - accuracy: 0.8958
# Epoch 881/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0348 - accuracy: 0.8958
# Epoch 882/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0348 - accuracy: 0.8958
# Epoch 883/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0350 - accuracy: 0.8958
# Epoch 884/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0350 - accuracy: 0.8958
# Epoch 885/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0346 - accuracy: 0.8958
# Epoch 886/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0346 - accuracy: 0.8958
# Epoch 887/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0346 - accuracy: 0.8958
# Epoch 888/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0344 - accuracy: 0.8958
# Epoch 889/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0344 - accuracy: 0.8958
# Epoch 890/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0345 - accuracy: 0.8958
# Epoch 891/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0344 - accuracy: 0.8958
# Epoch 892/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0345 - accuracy: 0.8958
# Epoch 893/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0342 - accuracy: 0.8958
# Epoch 894/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0343 - accuracy: 0.8958
# Epoch 895/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0342 - accuracy: 0.8958
# Epoch 896/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0340 - accuracy: 0.8958
# Epoch 897/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0341 - accuracy: 0.8958
# Epoch 898/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0340 - accuracy: 0.8958
# Epoch 899/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0339 - accuracy: 0.8958
# Epoch 900/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0338 - accuracy: 0.8958
# Epoch 901/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0339 - accuracy: 0.8958
# Epoch 902/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0338 - accuracy: 0.8958
# Epoch 903/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0338 - accuracy: 0.8958
# Epoch 904/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0336 - accuracy: 0.8958
# Epoch 905/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0337 - accuracy: 0.8958
# Epoch 906/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0336 - accuracy: 0.9167
# Epoch 907/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0337 - accuracy: 0.9167
# Epoch 908/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0335 - accuracy: 0.9167
# Epoch 909/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0334 - accuracy: 0.9167
# Epoch 910/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0333 - accuracy: 0.9167
# Epoch 911/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0332 - accuracy: 0.9167
# Epoch 912/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0333 - accuracy: 0.9167
# Epoch 913/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0332 - accuracy: 0.9167
# Epoch 914/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0330 - accuracy: 0.9167
# Epoch 915/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0332 - accuracy: 0.9167
# Epoch 916/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0329 - accuracy: 0.9167
# Epoch 917/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0329 - accuracy: 0.9167
# Epoch 918/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0330 - accuracy: 0.9167
# Epoch 919/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0329 - accuracy: 0.9167
# Epoch 920/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0329 - accuracy: 0.9167
# Epoch 921/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0328 - accuracy: 0.9167
# Epoch 922/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0328 - accuracy: 0.9167
# Epoch 923/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0327 - accuracy: 0.9167
# Epoch 924/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0326 - accuracy: 0.9167
# Epoch 925/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0325 - accuracy: 0.9167
# Epoch 926/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0325 - accuracy: 0.9167
# Epoch 927/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0324 - accuracy: 0.9167
# Epoch 928/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0323 - accuracy: 0.9167
# Epoch 929/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0324 - accuracy: 0.9167
# Epoch 930/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0323 - accuracy: 0.9167
# Epoch 931/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0325 - accuracy: 0.9167
# Epoch 932/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0321 - accuracy: 0.9167
# Epoch 933/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0323 - accuracy: 0.9167
# Epoch 934/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0320 - accuracy: 0.9167
# Epoch 935/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0321 - accuracy: 0.9167
# Epoch 936/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0320 - accuracy: 0.9167
# Epoch 937/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0319 - accuracy: 0.9167
# Epoch 938/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0319 - accuracy: 0.9167
# Epoch 939/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0318 - accuracy: 0.9167
# Epoch 940/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0320 - accuracy: 0.9167
# Epoch 941/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0318 - accuracy: 0.9167
# Epoch 942/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0317 - accuracy: 0.9167
# Epoch 943/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0317 - accuracy: 0.9167
# Epoch 944/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0317 - accuracy: 0.9167
# Epoch 945/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0315 - accuracy: 0.9167
# Epoch 946/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0315 - accuracy: 0.9167
# Epoch 947/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0315 - accuracy: 0.9167
# Epoch 948/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0315 - accuracy: 0.9167
# Epoch 949/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0313 - accuracy: 0.9167
# Epoch 950/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0312 - accuracy: 0.9167
# Epoch 951/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0313 - accuracy: 0.9167
# Epoch 952/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0312 - accuracy: 0.9167
# Epoch 953/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0311 - accuracy: 0.9167
# Epoch 954/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0313 - accuracy: 0.9167
# Epoch 955/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0312 - accuracy: 0.9167
# Epoch 956/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0309 - accuracy: 0.9167
# Epoch 957/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0310 - accuracy: 0.9167
# Epoch 958/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0308 - accuracy: 0.9167
# Epoch 959/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0308 - accuracy: 0.9167
# Epoch 960/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0307 - accuracy: 0.9167
# Epoch 961/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0308 - accuracy: 0.9167
# Epoch 962/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0307 - accuracy: 0.9167
# Epoch 963/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0306 - accuracy: 0.9167
# Epoch 964/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0305 - accuracy: 0.9167
# Epoch 965/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0305 - accuracy: 0.9167
# Epoch 966/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0305 - accuracy: 0.9167
# Epoch 967/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0305 - accuracy: 0.9167
# Epoch 968/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0305 - accuracy: 0.9167
# Epoch 969/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0302 - accuracy: 0.9167
# Epoch 970/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0303 - accuracy: 0.9167
# Epoch 971/1000
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0302 - accuracy: 0.9167
# Epoch 972/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0303 - accuracy: 0.9167
# Epoch 973/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0302 - accuracy: 0.9167
# Epoch 974/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0301 - accuracy: 0.9167
# Epoch 975/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0301 - accuracy: 0.9167
# Epoch 976/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0299 - accuracy: 0.9167
# Epoch 977/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0300 - accuracy: 0.9167
# Epoch 978/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0300 - accuracy: 0.9167
# Epoch 979/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0298 - accuracy: 0.9167
# Epoch 980/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0298 - accuracy: 0.9167
# Epoch 981/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0298 - accuracy: 0.9167
# Epoch 982/1000
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0298 - accuracy: 0.9167
# Epoch 983/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0296 - accuracy: 0.9167
# Epoch 984/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0295 - accuracy: 0.9167
# Epoch 985/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0295 - accuracy: 0.9167
# Epoch 986/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0295 - accuracy: 0.9167
# Epoch 987/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0294 - accuracy: 0.9167
# Epoch 988/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0294 - accuracy: 0.9167
# Epoch 989/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0293 - accuracy: 0.9167
# Epoch 990/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0292 - accuracy: 0.9167
# Epoch 991/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0291 - accuracy: 0.9167
# Epoch 992/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0291 - accuracy: 0.9167
# Epoch 993/1000
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0292 - accuracy: 0.9167
# Epoch 994/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0290 - accuracy: 0.9167
# Epoch 995/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0291 - accuracy: 0.9167
# Epoch 996/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0290 - accuracy: 0.9167
# Epoch 997/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0290 - accuracy: 0.9167
# Epoch 998/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0288 - accuracy: 0.9167
# Epoch 999/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0289 - accuracy: 0.9167
# Epoch 1000/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0288 - accuracy: 0.9167
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 206
#     198 # # saving to and loading from file
#     199 # z_model = f"Z_model.h5"
#     200 # print(f"Save model to file {z_model} ... ", end="")
#    (...)
#     203
#     204 #model already saved in file
#     205 from tensorflow.keras.models import  load_model
# --> 206 newmodel1= load_model("Zoghbio.h5",
#     207                           custom_objects={'RBFLayer': RBFLayer})
#     208 print("OK")
#     210 # Evaluate the model on the test data using `evaluate`
#
# File ~/Documents/401/CODE/Scorelate/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/Documents/401/CODE/Scorelate/venv/lib/python3.10/site-packages/keras/saving/save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at Zoghbio.h5
